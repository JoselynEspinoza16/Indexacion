# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("listings.csv")
df
# Out:
#                         id                                       listing_url  \
# 0                    18674                https://www.airbnb.com/rooms/18674
# 1                    23197                https://www.airbnb.com/rooms/23197
# 2                    32711                https://www.airbnb.com/rooms/32711
# 3                    34241                https://www.airbnb.com/rooms/34241
# 4                   347824               https://www.airbnb.com/rooms/347824
# ...                    ...                                               ...
# 18922  1440378586135901437  https://www.airbnb.com/rooms/1440378586135901437
# 18923  1440379191108051829  https://www.airbnb.com/rooms/1440379191108051829
# 18924  1440379869744969989  https://www.airbnb.com/rooms/1440379869744969989
# 18925  1440380503685655376  https://www.airbnb.com/rooms/1440380503685655376
# 18926  1440381140081945750  https://www.airbnb.com/rooms/1440381140081945750
#
# ...

# %%
punto_a= df.loc[:, ["host_name", "host_since", "neighbourhood", "property_type", "room_type", "price"]]

# %%
punto_a.to_csv("A.csv")

# %%
punto_b = df.iloc[[0, 49] + list(range(99, min(200, len(df))))]

# %%
punto_b.to_csv("B.csv")

# %%
filas_c = [125, 252] + list(range(300, 551)) + [700, 1000, 1250,]
columnas_c = ['host_id', 'host_location', 'host_acceptance_rate', 'bathrooms', 'amenities', 'review_scores_value']
punto_c = df.loc[filas_c, columnas_c]
punto_c
# Out:
#        host_id     host_location host_acceptance_rate  bathrooms  \
# 125    2846323  Barcelona, Spain                 100%        3.0
# 252    2041901  Barcelona, Spain                 100%        2.0
# 300    1432835  Barcelona, Spain                  90%        1.0
# 301    5126902  Barcelona, Spain                  89%        1.0
# 302     721378  Barcelona, Spain                 100%        2.0
# ...        ...               ...                  ...        ...
# 549    5878688  Barcelona, Spain                 100%        2.0
# 550    5878688  Barcelona, Spain                 100%        2.0
# 700    8232918  Barcelona, Spain                  39%        1.0
# 1000  17082106  Barcelona, Spain                  53%        1.0
# 1250  24661511  Barcelona, Spain                  97%        1.0
#
#                                               amenities  review_scores_value
# 125   ["Bed linens", "Oven", "AC - split type ductle...                 4.80
# ...

# %%
punto_c.to_csv("C.cvs")

# %%
columnas_seleccionadas = [
    'id', 'name', 'description',
    'host_id', 'host_name', 'host_since', 'host_location',
    'host_response_time', 'host_response_rate', 'host_acceptance_rate',
    'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
    'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
    'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed',
    'latitude', 'longitude','property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text',
    'bedrooms', 'beds', 'amenities',
    'price', 'minimum_nights', 'maximum_nights',
    'minimum_minimum_nights', 'maximum_minimum_nights',
    'minimum_maximum_nights', 'maximum_maximum_nights',
    'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
    'has_availability', 'availability_30', 'availability_60',
    'availability_90', 'availability_365', 'calendar_last_scraped',
    'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
    'review_scores_rating', 'review_scores_cleanliness', 'review_scores_value'
]
punto_d = df[columnas_seleccionadas]
punto_d
# Out:
#                         id                                               name  \
# 0                    18674    Huge flat for 8 people close to Sagrada Familia
# 1                    23197  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2                    32711                   Sagrada Familia area - Còrsega 1
# 3                    34241   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4                   347824  Ideal Happy Location Barceloneta Beach, Old Town!
# ...                    ...                                                ...
# 18922  1440378586135901437                           AB Marina Apartment I-II
# 18923  1440379191108051829                         AB Marina Apartment  III-I
# 18924  1440379869744969989                          AB Marina Apartment  IV-I
# 18925  1440380503685655376                   AB Sagrada Familia Views  VIII-I
# 18926  1440381140081945750                 AB Sagrada Familia - Sant Pau II-I
#
# ...

# %%
punto_d.to_csv("D.cvs")
